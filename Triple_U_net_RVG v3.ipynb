# %% [markdown]
# ## 1. Modules

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.ndimage import distance_transform_edt

# %% [markdown]
# ## 2. Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 3. Dataset

# %%
DRIVE_EXT = "/content/drive/My Drive/"
FOLDER_EXT = f"{DRIVE_EXT}/RVG_Merged_Dataset"
IMAGE_DIR = f"{FOLDER_EXT}/images"
MASK_DIR = f"{FOLDER_EXT}/masks_cleaned"

print("All extensions...")
print(DRIVE_EXT)
print(FOLDER_EXT)
print(IMAGE_DIR)
print(MASK_DIR)
# Out:
# All extensions...
# /content/drive/My Drive/
# /content/drive/My Drive//RVG_Merged_Dataset
# /content/drive/My Drive//RVG_Merged_Dataset/images
# /content/drive/My Drive//RVG_Merged_Dataset/masks_cleaned

# %%
len(os.listdir(IMAGE_DIR)), len(os.listdir(MASK_DIR))
# Out:
# (433, 434)

# %%
IMG_SIZE = (512, 512)
BATCH_SIZE = 2
AUTOTUNE = tf.data.AUTOTUNE

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=1)
    img = tf.cast(img, tf.float32) / 255.0

    img = tf.pad(
        img,
        paddings=[[5, 5], [10, 10], [0, 0]],
        mode="CONSTANT",
        constant_values=0.0
    )

    return img

def load_mask(mask_path):
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.cast(mask, tf.int32)
    mask = tf.pad(
        mask,
        paddings=[[5, 5], [10, 10], [0, 0]],
        mode="CONSTANT",
        constant_values=0
    )
    return mask

# %%
def make_binary_mask(mask, class_id):
    return tf.cast(mask == class_id, tf.float32)

# %%
def load_pair(img_path, mask_path, class_id):
    img  = load_image(img_path)
    mask = load_mask(mask_path)
    mask = make_binary_mask(mask, class_id)

    return img, mask

# %%
def get_matched_pairs():
    img_files = os.listdir(IMAGE_DIR)
    mask_files = os.listdir(MASK_DIR)

    img_map = {f.replace(".png", ""): os.path.join(IMAGE_DIR, f)
               for f in img_files}

    mask_map = {f.replace("_combined_mask.png", ""): os.path.join(MASK_DIR, f)
                for f in mask_files}

    common_keys = sorted(img_map.keys() & mask_map.keys())

    img_paths  = [img_map[k] for k in common_keys]
    mask_paths = [mask_map[k] for k in common_keys]

    return img_paths, mask_paths

# %%
def keep_only_correct_shape(img, mask):
    img_shape  = tf.shape(img)
    mask_shape = tf.shape(mask)

    img_ok = tf.logical_and(
        tf.logical_and(img_shape[0] == 800, img_shape[1] == 1120),
        img_shape[2] == 1
    )

    mask_ok = tf.logical_and(
        tf.logical_and(mask_shape[0] == 800, mask_shape[1] == 1120),
        mask_shape[2] == 1
    )

    return tf.logical_and(img_ok, mask_ok)

# %%
def create_binary_dataset(class_id):
    img_paths, mask_paths = get_matched_pairs()

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))

    ds = ds.map(
        lambda x, y: load_pair(x, y, class_id),
        num_parallel_calls=tf.data.AUTOTUNE
    )

    return ds

# %%
enamel_ds  = create_binary_dataset(class_id=1)
dentine_ds = create_binary_dataset(class_id=2)
pulp_ds    = create_binary_dataset(class_id=3)

enamel_ds = enamel_ds.filter(keep_only_correct_shape)
dentine_ds = dentine_ds.filter(keep_only_correct_shape)
pulp_ds = pulp_ds.filter(keep_only_correct_shape)

# %%
enamel_ds = (
    enamel_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
dentine_ds = (
    dentine_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
pulp_ds = (
    pulp_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# %%
N = sum(1 for _ in enamel_ds)

# %%
n_train = int(0.8 * N)
n_val   = int(0.1 * N)
n_test  = N - n_train - n_val
print("train: ", n_train)
print("val: ", n_val)
print("test: ", n_test)
# Out:
# train:  105
# val:  13
# test:  14

# %%
def split_ds(ds, nt, nv, ntt):
  return ds.take(nt), ds.take(nv), ds.take(ntt)

# %%
enamel_train, enamel_val, enamel_test = split_ds(enamel_ds, n_train, n_val, n_test)
dentine_train, dentine_val, dentine_test = split_ds(dentine_ds, n_train, n_val, n_test)
pulp_train, pulp_val, pulp_test = split_ds(pulp_ds, n_train, n_val, n_test)

# %% [markdown]
# ## 4. Model arch

# %%
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
    x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
    return x

def encoder_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPooling2D((2, 2))(c)
    return c, p

def decoder_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

# %%
def build_unet(input_shape=(None, None, 1)):
    inputs = layers.Input(input_shape)

    s1, p1 = encoder_block(inputs,   32)
    s2, p2 = encoder_block(p1,  64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    b = conv_block(p4, 512)

    d1 = decoder_block(b,  s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2,  64)
    d4 = decoder_block(d3, s1,  32)

    outputs = layers.Conv2D(1, (1, 1), activation="sigmoid")(d4)

    return Model(inputs, outputs)

# %% [markdown]
# ## 5. Crazy loss functions

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    intersection = tf.reduce_sum(y_true * y_pred)
    denom = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)

    dice = (2. * intersection + smooth) / (denom + smooth)
    return 1. - dice

def scce_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.int32)
    y_true = tf.squeeze(y_true, axis=-1)

    y_pred = tf.concat([1 - y_pred, y_pred], axis=-1)

    return tf.keras.losses.sparse_categorical_crossentropy(
        y_true, y_pred
    )

def focal_tversky_loss(y_true, y_pred,
                       alpha=0.4,
                       beta=0.6,
                       gamma=0.75,
                       smooth=1e-6):

    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    TP = tf.reduce_sum(y_true * y_pred)
    FP = tf.reduce_sum((1 - y_true) * y_pred)
    FN = tf.reduce_sum(y_true * (1 - y_pred))

    tversky = (TP + smooth) / (
        TP + alpha * FP + beta * FN + smooth
    )

    return tf.pow((1 - tversky), gamma)

def total_variation_loss(y_pred):
    return tf.reduce_mean(tf.image.total_variation(y_pred))

# %%
def combined_loss(y_true, y_pred):

    dice = dice_loss(y_true, y_pred)
    tversky = focal_tversky_loss(y_true, y_pred, alpha=0.3, beta=0.7)
    scce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    # tv = total_variation_loss(y_pred)

    return (
        dice +
        tversky +
        0.5 * scce
    )

# %% [markdown]
# ## 6. Crazy metrics to track everything

# %%
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    intersection = tf.reduce_sum(y_true * y_pred)
    denom = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)

    return (2. * intersection + smooth) / (denom + smooth)

def recall_sensitivity(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    TP = tf.reduce_sum(y_true * y_pred)
    FN = tf.reduce_sum(y_true * (1 - y_pred))

    return (TP + smooth) / (TP + FN + smooth)

def precision_metric(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    TP = tf.reduce_sum(y_true * y_pred)
    FP = tf.reduce_sum((1 - y_true) * y_pred)

    return (TP + smooth) / (TP + FP + smooth)

def hd95_metric(y_true, y_pred, threshold=0.5):
    """
    Computes the 95th percentile Hausdorff Distance
    """

    def _hd95(y_true_np, y_pred_np):
        y_true_np = y_true_np.astype(np.bool_)
        y_pred_np = (y_pred_np > threshold)

        if not np.any(y_true_np) and not np.any(y_pred_np):
            return np.array(0.0, dtype=np.float32)

        if not np.any(y_true_np) or not np.any(y_pred_np):
            return np.array(1e6, dtype=np.float32)

        dt_true = distance_transform_edt(~y_true_np)
        dt_pred = distance_transform_edt(~y_pred_np)

        surface_pred = dt_true[y_pred_np]
        surface_true = dt_pred[y_true_np]

        hd95 = np.percentile(
            np.concatenate([surface_pred, surface_true]),
            95
        )

        return np.array(hd95, dtype=np.float32)

    return tf.numpy_function(
        _hd95,
        [tf.squeeze(y_true), tf.squeeze(y_pred)],
        tf.float32
    )

# %% [markdown]
# ## 7. Callbacks (Not crazy)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

# %% [markdown]
# ## 8. Model building for enamel

# %%
enamel_model = build_unet()

enamel_model.compile(
    optimizer="adam",
    loss=combined_loss,
    metrics=[
        dice_coefficient,
        recall_sensitivity,
        precision_metric
        #hd95_metric  # Super slow
    ]
)

enamel_model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 1)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_172 (Conv2D) │ (None, None,      │        320 │ input_layer_11[0… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_173 (Conv2D) │ (None, None,      │      9,248 │ conv2d_172[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_40    │ (None, None,      │          0 │ conv2d_173[0][0]  │
# │ (MaxPooling2D)      │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_174 (Conv2D) │ (None, None,      │     18,496 │ max_pooling2d_40… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_175 (Conv2D) │ (None, None,      │     36,928 │ conv2d_174[0][0]  │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_41    │ (None, None,      │          0 │ conv2d_175[0][0]  │
# │ (MaxPooling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_176 (Conv2D) │ (None, None,      │     73,856 │ max_pooling2d_41… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_177 (Conv2D) │ (None, None,      │    147,584 │ conv2d_176[0][0]  │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_42    │ (None, None,      │          0 │ conv2d_177[0][0]  │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_178 (Conv2D) │ (None, None,      │    295,168 │ max_pooling2d_42… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_179 (Conv2D) │ (None, None,      │    590,080 │ conv2d_178[0][0]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_43    │ (None, None,      │          0 │ conv2d_179[0][0]  │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_180 (Conv2D) │ (None, None,      │  1,180,160 │ max_pooling2d_43… │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_181 (Conv2D) │ (None, None,      │  2,359,808 │ conv2d_180[0][0]  │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_34 │ (None, None,      │    524,544 │ conv2d_181[0][0]  │
# │ (Conv2DTranspose)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_34      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 512)        │            │ conv2d_179[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_182 (Conv2D) │ (None, None,      │  1,179,904 │ concatenate_34[0… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_183 (Conv2D) │ (None, None,      │    590,080 │ conv2d_182[0][0]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_35 │ (None, None,      │    131,200 │ conv2d_183[0][0]  │
# │ (Conv2DTranspose)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_35      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 256)        │            │ conv2d_177[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_184 (Conv2D) │ (None, None,      │    295,040 │ concatenate_35[0… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_185 (Conv2D) │ (None, None,      │    147,584 │ conv2d_184[0][0]  │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_36 │ (None, None,      │     32,832 │ conv2d_185[0][0]  │
# │ (Conv2DTranspose)   │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_36      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 128)        │            │ conv2d_175[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_186 (Conv2D) │ (None, None,      │     73,792 │ concatenate_36[0… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_187 (Conv2D) │ (None, None,      │     36,928 │ conv2d_186[0][0]  │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_37 │ (None, None,      │      8,224 │ conv2d_187[0][0]  │
# │ (Conv2DTranspose)   │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 64)         │            │ conv2d_173[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_188 (Conv2D) │ (None, None,      │     18,464 │ concatenate_37[0… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_189 (Conv2D) │ (None, None,      │      9,248 │ conv2d_188[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_190 (Conv2D) │ (None, None,      │         33 │ conv2d_189[0][0]  │
# │                     │ None, 1)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,759,521 (29.60 MB)
#  Trainable params: 7,759,521 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 9. Model training for enamel

# %%
enamel_history = enamel_model.fit(
    enamel_train,
    validation_data=enamel_val,
    epochs=50,
    # callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 68s 529ms/step - dice_coefficient: 0.2743 - loss: 1.6904 - precision_metric: 0.6983 - recall_sensitivity: 0.2525 - val_dice_coefficient: 0.5836 - val_loss: 1.0755 - val_precision_metric: 0.4866 - val_recall_sensitivity: 0.7569
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 505ms/step - dice_coefficient: 0.5265 - loss: 1.1866 - precision_metric: 0.5180 - recall_sensitivity: 0.6831 - val_dice_coefficient: 0.6283 - val_loss: 0.9708 - val_precision_metric: 0.6008 - val_recall_sensitivity: 0.7126
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 507ms/step - dice_coefficient: 0.5676 - loss: 1.0895 - precision_metric: 0.5457 - recall_sensitivity: 0.6908 - val_dice_coefficient: 0.6681 - val_loss: 0.8624 - val_precision_metric: 0.6260 - val_recall_sensitivity: 0.7704
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 506ms/step - dice_coefficient: 0.6350 - loss: 0.9397 - precision_metric: 0.5931 - recall_sensitivity: 0.7514 - val_dice_coefficient: 0.6593 - val_loss: 0.8833 - val_precision_metric: 0.6085 - val_recall_sensitivity: 0.7838
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 505ms/step - dice_coefficient: 0.6352 - loss: 0.9294 - precision_metric: 0.5775 - recall_sensitivity: 0.7718 - val_dice_coefficient: 0.6709 - val_loss: 0.8533 - val_precision_metric: 0.6040 - val_recall_sensitivity: 0.8255
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 506ms/step - dice_coefficient: 0.6464 - loss: 0.9087 - precision_metric: 0.6027 - recall_sensitivity: 0.7686 - val_dice_coefficient: 0.6918 - val_loss: 0.7984 - val_precision_metric: 0.6342 - val_recall_sensitivity: 0.8166
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 505ms/step - dice_coefficient: 0.6625 - loss: 0.8698 - precision_metric: 0.6194 - recall_sensitivity: 0.7804 - val_dice_coefficient: 0.7023 - val_loss: 0.7855 - val_precision_metric: 0.6764 - val_recall_sensitivity: 0.7822
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 505ms/step - dice_coefficient: 0.6677 - loss: 0.8571 - precision_metric: 0.6176 - recall_sensitivity: 0.7880 - val_dice_coefficient: 0.7143 - val_loss: 0.7468 - val_precision_metric: 0.6563 - val_recall_sensitivity: 0.8319
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 505ms/step - dice_coefficient: 0.6748 - loss: 0.8374 - precision_metric: 0.6217 - recall_sensitivity: 0.7956 - val_dice_coefficient: 0.7196 - val_loss: 0.7357 - val_precision_metric: 0.6743 - val_recall_sensitivity: 0.8177
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.6807 - loss: 0.8225 - precision_metric: 0.6284 - recall_sensitivity: 0.7988 - val_dice_coefficient: 0.7253 - val_loss: 0.7305 - val_precision_metric: 0.7148 - val_recall_sensitivity: 0.7870
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.6879 - loss: 0.8115 - precision_metric: 0.6456 - recall_sensitivity: 0.7939 - val_dice_coefficient: 0.7302 - val_loss: 0.7250 - val_precision_metric: 0.6811 - val_recall_sensitivity: 0.8315
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 505ms/step - dice_coefficient: 0.6916 - loss: 0.8073 - precision_metric: 0.6458 - recall_sensitivity: 0.8027 - val_dice_coefficient: 0.7276 - val_loss: 0.7161 - val_precision_metric: 0.6661 - val_recall_sensitivity: 0.8485
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.6942 - loss: 0.7950 - precision_metric: 0.6433 - recall_sensitivity: 0.8128 - val_dice_coefficient: 0.7192 - val_loss: 0.7346 - val_precision_metric: 0.6942 - val_recall_sensitivity: 0.8072
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.6935 - loss: 0.7946 - precision_metric: 0.6461 - recall_sensitivity: 0.8070 - val_dice_coefficient: 0.7359 - val_loss: 0.6924 - val_precision_metric: 0.6888 - val_recall_sensitivity: 0.8394
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.7060 - loss: 0.7641 - precision_metric: 0.6553 - recall_sensitivity: 0.8187 - val_dice_coefficient: 0.7369 - val_loss: 0.6976 - val_precision_metric: 0.6905 - val_recall_sensitivity: 0.8359
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.7138 - loss: 0.7467 - precision_metric: 0.6626 - recall_sensitivity: 0.8252 - val_dice_coefficient: 0.7504 - val_loss: 0.6663 - val_precision_metric: 0.7147 - val_recall_sensitivity: 0.8334
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.7187 - loss: 0.7367 - precision_metric: 0.6699 - recall_sensitivity: 0.8263 - val_dice_coefficient: 0.7352 - val_loss: 0.6946 - val_precision_metric: 0.6844 - val_recall_sensitivity: 0.8438
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.7195 - loss: 0.7306 - precision_metric: 0.6633 - recall_sensitivity: 0.8377 - val_dice_coefficient: 0.7424 - val_loss: 0.6731 - val_precision_metric: 0.6877 - val_recall_sensitivity: 0.8542
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.7238 - loss: 0.7201 - precision_metric: 0.6711 - recall_sensitivity: 0.8406 - val_dice_coefficient: 0.7172 - val_loss: 0.7344 - val_precision_metric: 0.6505 - val_recall_sensitivity: 0.8527
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.7086 - loss: 0.7598 - precision_metric: 0.6581 - recall_sensitivity: 0.8295 - val_dice_coefficient: 0.7484 - val_loss: 0.6719 - val_precision_metric: 0.7193 - val_recall_sensitivity: 0.8221
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.7327 - loss: 0.6997 - precision_metric: 0.6776 - recall_sensitivity: 0.8384 - val_dice_coefficient: 0.7516 - val_loss: 0.6522 - val_precision_metric: 0.7006 - val_recall_sensitivity: 0.8516
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.7325 - loss: 0.7025 - precision_metric: 0.6787 - recall_sensitivity: 0.8441 - val_dice_coefficient: 0.7519 - val_loss: 0.6642 - val_precision_metric: 0.7164 - val_recall_sensitivity: 0.8330
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.7378 - loss: 0.6883 - precision_metric: 0.6858 - recall_sensitivity: 0.8434 - val_dice_coefficient: 0.7647 - val_loss: 0.6479 - val_precision_metric: 0.7558 - val_recall_sensitivity: 0.8104
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.7460 - loss: 0.6712 - precision_metric: 0.6951 - recall_sensitivity: 0.8466 - val_dice_coefficient: 0.7615 - val_loss: 0.6707 - val_precision_metric: 0.8121 - val_recall_sensitivity: 0.7570
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 503ms/step - dice_coefficient: 0.7358 - loss: 0.6961 - precision_metric: 0.6898 - recall_sensitivity: 0.8288 - val_dice_coefficient: 0.7786 - val_loss: 0.6154 - val_precision_metric: 0.7881 - val_recall_sensitivity: 0.8080
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 504ms/step - dice_coefficient: 0.7573 - loss: 0.6446 - precision_metric: 0.7073 - recall_sensitivity: 0.8570 - val_dice_coefficient: 0.7877 - val_loss: 0.5849 - val_precision_metric: 0.7797 - val_recall_sensitivity: 0.8344
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 502ms/step - dice_coefficient: 0.7559 - loss: 0.6487 - precision_metric: 0.7075 - recall_sensitivity: 0.8541 - val_dice_coefficient: 0.7725 - val_loss: 0.6306 - val_precision_metric: 0.7781 - val_recall_sensitivity: 0.8023
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 502ms/step - dice_coefficient: 0.7663 - loss: 0.6245 - precision_metric: 0.7197 - recall_sensitivity: 0.8564 - val_dice_coefficient: 0.7708 - val_loss: 0.6196 - val_precision_metric: 0.7419 - val_recall_sensitivity: 0.8416
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 502ms/step - dice_coefficient: 0.7671 - loss: 0.6234 - precision_metric: 0.7234 - recall_sensitivity: 0.8573 - val_dice_coefficient: 0.7852 - val_loss: 0.5928 - val_precision_metric: 0.7806 - val_recall_sensitivity: 0.8301
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.7694 - loss: 0.6191 - precision_metric: 0.7279 - recall_sensitivity: 0.8575 - val_dice_coefficient: 0.7874 - val_loss: 0.5772 - val_precision_metric: 0.7469 - val_recall_sensitivity: 0.8686
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 502ms/step - dice_coefficient: 0.7663 - loss: 0.6287 - precision_metric: 0.7267 - recall_sensitivity: 0.8562 - val_dice_coefficient: 0.8035 - val_loss: 0.5365 - val_precision_metric: 0.7711 - val_recall_sensitivity: 0.8721
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 502ms/step - dice_coefficient: 0.7763 - loss: 0.6001 - precision_metric: 0.7296 - recall_sensitivity: 0.8710 - val_dice_coefficient: 0.7905 - val_loss: 0.5668 - val_precision_metric: 0.7258 - val_recall_sensitivity: 0.8975
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.7797 - loss: 0.5952 - precision_metric: 0.7341 - recall_sensitivity: 0.8736 - val_dice_coefficient: 0.8031 - val_loss: 0.5457 - val_precision_metric: 0.7645 - val_recall_sensitivity: 0.8721
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 85s 812ms/step - dice_coefficient: 0.7829 - loss: 0.5860 - precision_metric: 0.7379 - recall_sensitivity: 0.8715 - val_dice_coefficient: 0.8084 - val_loss: 0.5376 - val_precision_metric: 0.7845 - val_recall_sensitivity: 0.8592
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 500ms/step - dice_coefficient: 0.7924 - loss: 0.5640 - precision_metric: 0.7466 - recall_sensitivity: 0.8770 - val_dice_coefficient: 0.8137 - val_loss: 0.5199 - val_precision_metric: 0.7750 - val_recall_sensitivity: 0.8821
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 502ms/step - dice_coefficient: 0.7922 - loss: 0.5658 - precision_metric: 0.7484 - recall_sensitivity: 0.8761 - val_dice_coefficient: 0.8124 - val_loss: 0.5267 - val_precision_metric: 0.7667 - val_recall_sensitivity: 0.8859
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.7957 - loss: 0.5562 - precision_metric: 0.7495 - recall_sensitivity: 0.8804 - val_dice_coefficient: 0.8147 - val_loss: 0.5240 - val_precision_metric: 0.7633 - val_recall_sensitivity: 0.8945
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8009 - loss: 0.5433 - precision_metric: 0.7523 - recall_sensitivity: 0.8871 - val_dice_coefficient: 0.8370 - val_loss: 0.4669 - val_precision_metric: 0.8049 - val_recall_sensitivity: 0.8926
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8059 - loss: 0.5319 - precision_metric: 0.7617 - recall_sensitivity: 0.8835 - val_dice_coefficient: 0.8326 - val_loss: 0.4836 - val_precision_metric: 0.8166 - val_recall_sensitivity: 0.8715
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8089 - loss: 0.5251 - precision_metric: 0.7656 - recall_sensitivity: 0.8855 - val_dice_coefficient: 0.8289 - val_loss: 0.4820 - val_precision_metric: 0.7810 - val_recall_sensitivity: 0.9020
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8100 - loss: 0.5205 - precision_metric: 0.7607 - recall_sensitivity: 0.8938 - val_dice_coefficient: 0.8308 - val_loss: 0.4811 - val_precision_metric: 0.8060 - val_recall_sensitivity: 0.8802
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8200 - loss: 0.4931 - precision_metric: 0.7695 - recall_sensitivity: 0.9023 - val_dice_coefficient: 0.8190 - val_loss: 0.5417 - val_precision_metric: 0.8549 - val_recall_sensitivity: 0.8065
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 500ms/step - dice_coefficient: 0.8267 - loss: 0.4811 - precision_metric: 0.7836 - recall_sensitivity: 0.8968 - val_dice_coefficient: 0.8301 - val_loss: 0.5095 - val_precision_metric: 0.8621 - val_recall_sensitivity: 0.8205
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 500ms/step - dice_coefficient: 0.8271 - loss: 0.4807 - precision_metric: 0.7873 - recall_sensitivity: 0.8940 - val_dice_coefficient: 0.8198 - val_loss: 0.5298 - val_precision_metric: 0.8342 - val_recall_sensitivity: 0.8262
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8245 - loss: 0.4851 - precision_metric: 0.7816 - recall_sensitivity: 0.8957 - val_dice_coefficient: 0.8492 - val_loss: 0.4472 - val_precision_metric: 0.8424 - val_recall_sensitivity: 0.8730
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8416 - loss: 0.4461 - precision_metric: 0.8032 - recall_sensitivity: 0.9047 - val_dice_coefficient: 0.8657 - val_loss: 0.4108 - val_precision_metric: 0.8612 - val_recall_sensitivity: 0.8830
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 500ms/step - dice_coefficient: 0.8476 - loss: 0.4330 - precision_metric: 0.8122 - recall_sensitivity: 0.9073 - val_dice_coefficient: 0.8594 - val_loss: 0.4238 - val_precision_metric: 0.8436 - val_recall_sensitivity: 0.8876
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 500ms/step - dice_coefficient: 0.8565 - loss: 0.4106 - precision_metric: 0.8219 - recall_sensitivity: 0.9119 - val_dice_coefficient: 0.8520 - val_loss: 0.4337 - val_precision_metric: 0.8212 - val_recall_sensitivity: 0.8993
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8524 - loss: 0.4212 - precision_metric: 0.8172 - recall_sensitivity: 0.9100 - val_dice_coefficient: 0.8701 - val_loss: 0.3862 - val_precision_metric: 0.8432 - val_recall_sensitivity: 0.9106
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 53s 501ms/step - dice_coefficient: 0.8644 - loss: 0.3922 - precision_metric: 0.8313 - recall_sensitivity: 0.9165 - val_dice_coefficient: 0.8665 - val_loss: 0.3970 - val_precision_metric: 0.8435 - val_recall_sensitivity: 0.9016

# %%
history = enamel_history.history
epochs = range(1, len(history['loss']) + 1)

plt.figure(figsize=(14, 10))

# 1️⃣ Dice
plt.subplot(2, 2, 1)
plt.plot(epochs, history['dice_coefficient'], label='Train Dice')
plt.plot(epochs, history['val_dice_coefficient'], label='Val Dice')
plt.title('Dice Coefficient')
plt.xlabel('Epoch')
plt.ylabel('Dice')
plt.legend()
plt.grid(True)

# 2️⃣ Loss
plt.subplot(2, 2, 2)
plt.plot(epochs, history['loss'], label='Train Loss')
plt.plot(epochs, history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# 3️⃣ Precision
plt.subplot(2, 2, 3)
plt.plot(epochs, history['precision_metric'], label='Train Precision')
plt.plot(epochs, history['val_precision_metric'], label='Val Precision')
plt.title('Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

# 4️⃣ Recall
plt.subplot(2, 2, 4)
plt.plot(epochs, history['recall_sensitivity'], label='Train Recall')
plt.plot(epochs, history['val_recall_sensitivity'], label='Val Recall')
plt.title('Recall (Sensitivity)')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.savefig("LossCurves.png", dpi=400)
plt.tight_layout()
plt.show()

# %%
test_results = enamel_model.evaluate(enamel_test, verbose=1)

test_metrics = dict(zip(enamel_model.metrics_names, test_results))
test_metrics
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - dice_coefficient: 0.8662 - loss: 0.3872 - precision_metric: 0.8315 - recall_sensitivity: 0.9141
# {'loss': 0.4161112308502197, 'compile_metrics': 0.858573853969574}

# %%
images, gts = next(iter(enamel_test))
preds = enamel_model.predict(images)

batch_size = images.shape[0]
threshold = 0.2   # try 0.3 later if recall is low
alpha = 0.5       # transparency for overlays

plt.figure(figsize=(15, 4 * batch_size))

for i in range(batch_size):
    img  = images[i, ..., 0]
    gt   = gts[i, ..., 0]
    pred = preds[i, ..., 0]

    # 1️⃣ Image only
    plt.subplot(batch_size, 3, i * 3 + 1)
    plt.imshow(img, cmap="gray")
    plt.title(f"Image {i}")
    plt.axis("off")

    # 2️⃣ Image + GT overlay
    plt.subplot(batch_size, 3, i * 3 + 2)
    plt.imshow(img, cmap="gray")
    plt.imshow(gt, cmap="Reds", alpha=alpha)
    plt.title(f"Image + GT {i}")
    plt.axis("off")

    # 3️⃣ Image + Prediction overlay
    plt.subplot(batch_size, 3, i * 3 + 3)
    plt.imshow(img, cmap="gray")
    plt.imshow(pred > threshold, cmap="Blues", alpha=alpha)
    plt.title(f"Image + Pred {i}")
    plt.axis("off")

plt.gcf().text(
    0.5, 0.02,
    f"Test metrics: {test_metrics}",
    ha="center",
    va="center",
    fontsize=12
)

plt.tight_layout()
plt.savefig("prediction_overlay.png", dpi=400,)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step

# %% [markdown]
# ## 10. Model building for Dentine

# %%
dentine_model = build_unet()

dentine_model.compile(
    optimizer="adam",
    loss=combined_loss,
    metrics=[
        dice_coefficient,
        recall_sensitivity,
        precision_metric
    ]
)

dentine_model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 1)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_191 (Conv2D) │ (None, None,      │        320 │ input_layer_12[0… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_192 (Conv2D) │ (None, None,      │      9,248 │ conv2d_191[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_44    │ (None, None,      │          0 │ conv2d_192[0][0]  │
# │ (MaxPooling2D)      │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_193 (Conv2D) │ (None, None,      │     18,496 │ max_pooling2d_44… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_194 (Conv2D) │ (None, None,      │     36,928 │ conv2d_193[0][0]  │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_45    │ (None, None,      │          0 │ conv2d_194[0][0]  │
# │ (MaxPooling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_195 (Conv2D) │ (None, None,      │     73,856 │ max_pooling2d_45… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, None,      │    147,584 │ conv2d_195[0][0]  │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_46    │ (None, None,      │          0 │ conv2d_196[0][0]  │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, None,      │    295,168 │ max_pooling2d_46… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_198 (Conv2D) │ (None, None,      │    590,080 │ conv2d_197[0][0]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_47    │ (None, None,      │          0 │ conv2d_198[0][0]  │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_199 (Conv2D) │ (None, None,      │  1,180,160 │ max_pooling2d_47… │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_200 (Conv2D) │ (None, None,      │  2,359,808 │ conv2d_199[0][0]  │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_38 │ (None, None,      │    524,544 │ conv2d_200[0][0]  │
# │ (Conv2DTranspose)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 512)        │            │ conv2d_198[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_201 (Conv2D) │ (None, None,      │  1,179,904 │ concatenate_38[0… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_202 (Conv2D) │ (None, None,      │    590,080 │ conv2d_201[0][0]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_39 │ (None, None,      │    131,200 │ conv2d_202[0][0]  │
# │ (Conv2DTranspose)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 256)        │            │ conv2d_196[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_203 (Conv2D) │ (None, None,      │    295,040 │ concatenate_39[0… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_204 (Conv2D) │ (None, None,      │    147,584 │ conv2d_203[0][0]  │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_40 │ (None, None,      │     32,832 │ conv2d_204[0][0]  │
# │ (Conv2DTranspose)   │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 128)        │            │ conv2d_194[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_205 (Conv2D) │ (None, None,      │     73,792 │ concatenate_40[0… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_206 (Conv2D) │ (None, None,      │     36,928 │ conv2d_205[0][0]  │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_41 │ (None, None,      │      8,224 │ conv2d_206[0][0]  │
# │ (Conv2DTranspose)   │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 64)         │            │ conv2d_192[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_207 (Conv2D) │ (None, None,      │     18,464 │ concatenate_41[0… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_208 (Conv2D) │ (None, None,      │      9,248 │ conv2d_207[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_209 (Conv2D) │ (None, None,      │         33 │ conv2d_208[0][0]  │
# │                     │ None, 1)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,759,521 (29.60 MB)
#  Trainable params: 7,759,521 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
dentine_history = dentine_model.fit(
    dentine_train,
    validation_data=dentine_val,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
#      14/Unknown 19s 481ms/step - dice_coefficient: 0.3111 - loss: 1.7585 - precision_metric: 0.2745 - recall_sensitivity: 0.9686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-947985973.py in <cell line: 0>()
# ----> 1 dentine_history = dentine_model.fit(
#       2     dentine_train,
#       3     validation_data=dentine_val,
#       4     epochs=50,
#       5     verbose=1
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     219             ):
#     220                 opt_outputs = multi_step_on_iterator(iterator)
# --> 221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#     223                 return opt_outputs.get_value()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/optional_ops.py in has_value(self, name)
#     174   def has_value(self, name=None):
#     175     with ops.colocate_with(self._variant_tensor):
# --> 176       return gen_optional_ops.optional_has_value(
#     177           self._variant_tensor, name=name
#     178       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_optional_ops.py in optional_has_value(optional, name)
#     170   if tld.is_eager:
#     171     try:
# --> 172       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173         _ctx, "OptionalHasValue", name, optional)
#     174       return _result
#
# KeyboardInterrupt:

# %%
history = dentine_history.history
epochs = range(1, len(history['loss']) + 1)

plt.figure(figsize=(14, 10))

# 1️⃣ Dice
plt.subplot(2, 2, 1)
plt.plot(epochs, history['dice_coefficient'], label='Train Dice')
plt.plot(epochs, history['val_dice_coefficient'], label='Val Dice')
plt.title('Dice Coefficient')
plt.xlabel('Epoch')
plt.ylabel('Dice')
plt.legend()
plt.grid(True)

# 2️⃣ Loss
plt.subplot(2, 2, 2)
plt.plot(epochs, history['loss'], label='Train Loss')
plt.plot(epochs, history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# 3️⃣ Precision
plt.subplot(2, 2, 3)
plt.plot(epochs, history['precision_metric'], label='Train Precision')
plt.plot(epochs, history['val_precision_metric'], label='Val Precision')
plt.title('Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

# 4️⃣ Recall
plt.subplot(2, 2, 4)
plt.plot(epochs, history['recall_sensitivity'], label='Train Recall')
plt.plot(epochs, history['val_recall_sensitivity'], label='Val Recall')
plt.title('Recall (Sensitivity)')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.savefig("LossCurves_dentine.png", dpi=400)
plt.tight_layout()
plt.show()

# %%
test_results = dentine_model.evaluate(dentine_test, verbose=1)

test_metrics = dict(zip(dentine_model.metrics_names, test_results))
test_metrics

# %%
images, gts = next(iter(dentine_test))
preds = dentine_model.predict(images)

batch_size = images.shape[0]
threshold = 0.2   # try 0.3 later if recall is low
alpha = 0.5       # transparency for overlays

plt.figure(figsize=(15, 4 * batch_size))

for i in range(batch_size):
    img  = images[i, ..., 0]
    gt   = gts[i, ..., 0]
    pred = preds[i, ..., 0]

    # 1️⃣ Image only
    plt.subplot(batch_size, 3, i * 3 + 1)
    plt.imshow(img, cmap="gray")
    plt.title(f"Image {i}")
    plt.axis("off")

    # 2️⃣ Image + GT overlay
    plt.subplot(batch_size, 3, i * 3 + 2)
    plt.imshow(img, cmap="gray")
    plt.imshow(gt, cmap="Reds", alpha=alpha)
    plt.title(f"Image + GT {i}")
    plt.axis("off")

    # 3️⃣ Image + Prediction overlay
    plt.subplot(batch_size, 3, i * 3 + 3)
    plt.imshow(img, cmap="gray")
    plt.imshow(pred > threshold, cmap="Blues", alpha=alpha)
    plt.title(f"Image + Pred {i}")
    plt.axis("off")

plt.gcf().text(
    0.5, 0.02,
    f"Test metrics: {test_metrics}",
    ha="center",
    va="center",
    fontsize=12
)

plt.tight_layout()
plt.savefig("prediction_overlay_dentine.png", dpi=400,)
plt.show()

# %% [markdown]
# ## 11. Model for Pulp
#
# Loss function changes

# %%
def focal_tversky_loss_dentine(y_true, y_pred, alpha=0.2, beta=0.8, gamma=0.75, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    tp = tf.reduce_sum(y_true * y_pred)
    fn = tf.reduce_sum(y_true * (1 - y_pred))
    fp = tf.reduce_sum((1 - y_true) * y_pred)

    tversky = (tp + smooth) / (tp + alpha * fp + beta * fn + smooth)
    return tf.pow((1 - tversky), gamma)

def soft_dice_loss_dentine(y_true, y_pred, smooth=1e-6):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    return 1 - (2. * intersection + smooth) / (union + smooth)

def pulp_loss(y_true, y_pred):
    return (
        focal_tversky_loss_dentine(y_true, y_pred, alpha=0.2, beta=0.8, gamma=0.75)
        + 0.2 * soft_dice_loss_dentine(y_true, y_pred)
    )

# %%
pulp_model = build_unet()

pulp_model.compile(
    optimizer="adam",
    loss=pulp_loss,
    metrics=[
        dice_coefficient,
        recall_sensitivity,
        precision_metric
    ]
)

pulp_model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 1)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_210 (Conv2D) │ (None, None,      │        320 │ input_layer_13[0… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_211 (Conv2D) │ (None, None,      │      9,248 │ conv2d_210[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_48    │ (None, None,      │          0 │ conv2d_211[0][0]  │
# │ (MaxPooling2D)      │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_212 (Conv2D) │ (None, None,      │     18,496 │ max_pooling2d_48… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_213 (Conv2D) │ (None, None,      │     36,928 │ conv2d_212[0][0]  │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_49    │ (None, None,      │          0 │ conv2d_213[0][0]  │
# │ (MaxPooling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_214 (Conv2D) │ (None, None,      │     73,856 │ max_pooling2d_49… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_215 (Conv2D) │ (None, None,      │    147,584 │ conv2d_214[0][0]  │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_50    │ (None, None,      │          0 │ conv2d_215[0][0]  │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_216 (Conv2D) │ (None, None,      │    295,168 │ max_pooling2d_50… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_217 (Conv2D) │ (None, None,      │    590,080 │ conv2d_216[0][0]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_51    │ (None, None,      │          0 │ conv2d_217[0][0]  │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_218 (Conv2D) │ (None, None,      │  1,180,160 │ max_pooling2d_51… │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_219 (Conv2D) │ (None, None,      │  2,359,808 │ conv2d_218[0][0]  │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_42 │ (None, None,      │    524,544 │ conv2d_219[0][0]  │
# │ (Conv2DTranspose)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_42      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 512)        │            │ conv2d_217[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_220 (Conv2D) │ (None, None,      │  1,179,904 │ concatenate_42[0… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_221 (Conv2D) │ (None, None,      │    590,080 │ conv2d_220[0][0]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_43 │ (None, None,      │    131,200 │ conv2d_221[0][0]  │
# │ (Conv2DTranspose)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_43      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 256)        │            │ conv2d_215[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_222 (Conv2D) │ (None, None,      │    295,040 │ concatenate_43[0… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_223 (Conv2D) │ (None, None,      │    147,584 │ conv2d_222[0][0]  │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_44 │ (None, None,      │     32,832 │ conv2d_223[0][0]  │
# │ (Conv2DTranspose)   │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_44      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 128)        │            │ conv2d_213[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_224 (Conv2D) │ (None, None,      │     73,792 │ concatenate_44[0… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_225 (Conv2D) │ (None, None,      │     36,928 │ conv2d_224[0][0]  │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_45 │ (None, None,      │      8,224 │ conv2d_225[0][0]  │
# │ (Conv2DTranspose)   │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_45      │ (None, None,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ None, 64)         │            │ conv2d_211[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_226 (Conv2D) │ (None, None,      │     18,464 │ concatenate_45[0… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_227 (Conv2D) │ (None, None,      │      9,248 │ conv2d_226[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_228 (Conv2D) │ (None, None,      │         33 │ conv2d_227[0][0]  │
# │                     │ None, 1)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,759,521 (29.60 MB)
#  Trainable params: 7,759,521 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
pulp_history = pulp_model.fit(
    pulp_train,
    validation_data=pulp_val,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
#       5/Unknown 14s 480ms/step - dice_coefficient: 0.0781 - loss: 1.0615 - precision_metric: 0.0414 - recall_sensitivity: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2943167778.py in <cell line: 0>()
# ----> 1 pulp_history = pulp_model.fit(
#       2     pulp_train,
#       3     validation_data=pulp_val,
#       4     epochs=50,
#       5     verbose=1
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     219             ):
#     220                 opt_outputs = multi_step_on_iterator(iterator)
# --> 221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#     223                 return opt_outputs.get_value()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/optional_ops.py in has_value(self, name)
#     174   def has_value(self, name=None):
#     175     with ops.colocate_with(self._variant_tensor):
# --> 176       return gen_optional_ops.optional_has_value(
#     177           self._variant_tensor, name=name
#     178       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_optional_ops.py in optional_has_value(optional, name)
#     170   if tld.is_eager:
#     171     try:
# --> 172       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173         _ctx, "OptionalHasValue", name, optional)
#     174       return _result
#
# KeyboardInterrupt:

# %%
history = pulp_history.history
epochs = range(1, len(history['loss']) + 1)

plt.figure(figsize=(14, 10))

# 1️⃣ Dice
plt.subplot(2, 2, 1)
plt.plot(epochs, history['dice_coefficient'], label='Train Dice')
plt.plot(epochs, history['val_dice_coefficient'], label='Val Dice')
plt.title('Dice Coefficient')
plt.xlabel('Epoch')
plt.ylabel('Dice')
plt.legend()
plt.grid(True)

# 2️⃣ Loss
plt.subplot(2, 2, 2)
plt.plot(epochs, history['loss'], label='Train Loss')
plt.plot(epochs, history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# 3️⃣ Precision
plt.subplot(2, 2, 3)
plt.plot(epochs, history['precision_metric'], label='Train Precision')
plt.plot(epochs, history['val_precision_metric'], label='Val Precision')
plt.title('Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

# 4️⃣ Recall
plt.subplot(2, 2, 4)
plt.plot(epochs, history['recall_sensitivity'], label='Train Recall')
plt.plot(epochs, history['val_recall_sensitivity'], label='Val Recall')
plt.title('Recall (Sensitivity)')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.savefig("LossCurves_pulp.png", dpi=400)
plt.tight_layout()
plt.show()

# %%
images, gts = next(iter(pulp_test))
preds = pulp_model.predict(images)

batch_size = images.shape[0]
threshold = 0.2   # try 0.3 later if recall is low
alpha = 0.5       # transparency for overlays

plt.figure(figsize=(15, 4 * batch_size))

for i in range(batch_size):
    img  = images[i, ..., 0]
    gt   = gts[i, ..., 0]
    pred = preds[i, ..., 0]

    # 1️⃣ Image only
    plt.subplot(batch_size, 3, i * 3 + 1)
    plt.imshow(img, cmap="gray")
    plt.title(f"Image {i}")
    plt.axis("off")

    # 2️⃣ Image + GT overlay
    plt.subplot(batch_size, 3, i * 3 + 2)
    plt.imshow(img, cmap="gray")
    plt.imshow(gt, cmap="Reds", alpha=alpha)
    plt.title(f"Image + GT {i}")
    plt.axis("off")

    # 3️⃣ Image + Prediction overlay
    plt.subplot(batch_size, 3, i * 3 + 3)
    plt.imshow(img, cmap="gray")
    plt.imshow(pred > threshold, cmap="Blues", alpha=alpha)
    plt.title(f"Image + Pred {i}")
    plt.axis("off")

plt.gcf().text(
    0.5, 0.02,
    f"Test metrics: {test_metrics}",
    ha="center",
    va="center",
    fontsize=12
)

plt.tight_layout()
plt.savefig("prediction_overlay_pulp.png", dpi=400,)
plt.show()
